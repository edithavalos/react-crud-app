# %% [markdown]
# <a href="https://colab.research.google.com/github/edithavalos/react-crud-app/blob/master/Ejercicios_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ClassicModels
# El esquema es para Classic Models, un minorista de modelos a escala de coches clásicos. La base de datos contiene datos comerciales típicos, como clientes, pedidos, artículos de línea de pedido, productos, etc.
#
# Fuente original: www.mysqltutorial.org

# %% [markdown]
# ![classicmodels[1].svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ### Ejercicios de SQL utilizando el esquema de base de datos ClassicModels:
#
# 1. Obtén todos los registros de la tabla `customers`.
#
# 2. Muestra todos los productos de la tabla `products` cuyo precio de compra (`buyPrice`) sea mayor a 50.
#
# 3. Lista los empleados que trabajan en la oficina con código `officeCode` igual a 1.
#
# 4. Encuentra todos los clientes cuyo nombre (`customerName`) comienza con la letra 'A'.
#
# 5. Cuenta cuántos pedidos (`orders`) ha realizado el cliente con número de cliente (`customerNumber`) 103.
#
# 6. Calcula el total de pagos realizados por el cliente con número de cliente 112.
#
# 7. Encuentra el producto con el precio de compra más alto en la tabla `products`.
#
# 8. Muestra los 5 productos más vendidos según la cantidad pedida en `orderdetails`.
#
# 9. Lista todas las oficinas y el número de empleados que trabajan en cada una.
#
# 10. Encuentra el número total de clientes atendidos por cada representante de ventas (`salesRepEmployeeNumber`).
#
# 11. Muestra todos los productos y su línea de producto (`productLine`), ordenados alfabéticamente por línea de producto.
#
# 12. Calcula el importe total de todas las órdenes sumando el resultado de `quantityOrdered` por `priceEach` en `orderdetails`.
#
# 13. Encuentra todos los pedidos que han sido enviados después del 1 de enero de 2004.
#
# 14. Lista los clientes y sus pagos totales, ordenados de mayor a menor.
#
# 15. Muestra los empleados que no reportan a ningún gerente (es decir, cuyo campo `reportsTo` es NULL).
#
# 16. Encuentra los clientes que no han realizado ningún pedido.
#
# 17. Muestra los productos que nunca han sido vendidos en ningún pedido.
#
# 18. Calcula el precio de compra promedio de todos los productos.
#
# 19. Lista los clientes y el número de pedidos que han realizado.
#
# 20. Encuentra el total de ventas por año.
#
# 21. Muestra los detalles de las órdenes combinados con la información del producto para cada artículo.
#
# 22. Encuentra los empleados que trabajan en oficinas ubicadas en los Estados Unidos.
#
# 23. Lista los clientes junto con el nombre de su representante de ventas.
#
# 24. Calcula el total de pagos recibidos en cada ciudad.
#
# 25. Muestra los productos que tienen menos de 100 unidades en stock (`quantityInStock`).
#
# 26. Encuentra los clientes que han realizado pedidos con un monto total superior a $10,000.
#
# 27. Lista los empleados y el número de clientes que atienden.
#
# 28. Calcula el importe total de los pedidos que están en proceso (estado 'In Process').
#
# 29. Encuentra los productos que han sido pedidos más de 100 veces en total.
#
# 30. Muestra las líneas de productos y el número de productos que pertenecen a cada línea.
#
# Estos ejercicios abarcan diversas consultas y operaciones que pueden realizarse en la base de datos ClassicModels, incluyendo selección, agregación, ordenamiento, uniones y subconsultas.

# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
# %%capture
# !apt-get install postgresql postgresql-contrib
# !pip install ipython-sql psycopg2-binary pymysql sqlalchemy

# %%
# !service postgresql start
# !sudo -u postgres createdb classicmodels
# !sudo -u postgres psql -c "ALTER USER postgres PASSWORD 'postgres';"
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.
# ALTER ROLE

# %%
# %load_ext sql
# %sql postgresql://postgres:postgres@localhost/classicmodels

# %%
import pandas as pd
from sqlalchemy import create_engine, inspect

# Parámetros de conexión para MariaDB
mariadb_usuario = 'guest'
mariadb_contraseña = 'relational'
mariadb_host = 'db.relational-data.org'  # o la dirección de tu host
mariadb_puerto = 3306  # Puerto por defecto para MariaDB/MySQL
mariadb_base_datos = 'classicmodels'

# Parámetros de conexión para PostgreSQL
postgres_usuario = 'postgres'
postgres_contraseña = 'postgres'
postgres_host = 'localhost'  # o la dirección de tu host
postgres_puerto = 5432  # Puerto por defecto para PostgreSQL
postgres_base_datos = 'classicmodels'

# Crear el motor de conexión para MariaDB
mariadb_engine = create_engine(
    f'mysql+pymysql://{mariadb_usuario}:{mariadb_contraseña}@{mariadb_host}:{mariadb_puerto}/{mariadb_base_datos}'
)

# Crear el motor de conexión para PostgreSQL
postgres_engine = create_engine(
    f'postgresql+psycopg2://{postgres_usuario}:{postgres_contraseña}@{postgres_host}:{postgres_puerto}/{postgres_base_datos}'
)

# Obtener la lista de tablas de MariaDB
inspector = inspect(mariadb_engine)
tablas = inspector.get_table_names()

# Iterar sobre las tablas y copiarlas a PostgreSQL
for nombre_tabla in tablas:
    print(f"Procesando la tabla {nombre_tabla}")
    df = pd.read_sql_table(nombre_tabla, mariadb_engine)
    df.to_sql(nombre_tabla, postgres_engine, index=False, if_exists='replace')
    print(f"Tabla {nombre_tabla} copiada exitosamente.")
# Out:
# Procesando la tabla customers
# Tabla customers copiada exitosamente.
# Procesando la tabla employees
# Tabla employees copiada exitosamente.
# Procesando la tabla offices
# Tabla offices copiada exitosamente.
# Procesando la tabla orderdetails
# Tabla orderdetails copiada exitosamente.
# Procesando la tabla orders
# Tabla orders copiada exitosamente.
# Procesando la tabla payments
# Tabla payments copiada exitosamente.
# Procesando la tabla productlines
# Tabla productlines copiada exitosamente.
# Procesando la tabla products
# Tabla products copiada exitosamente.

# %%
# %%sql
#
# select *
# from customers
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [(103, 'Atelier graphique', 'Schmitt', 'Carine ', '40.32.2555', '54, rue Royale', None, 'Nantes', None, '44000', 'France', 1370.0, 21000.0),
#  (112, 'Signal Gift Stores', 'King', 'Jean', '7025551838', '8489 Strong St.', None, 'Las Vegas', 'NV', '83030', 'USA', 1166.0, 71800.0),
#  (114, 'Australian Collectors, Co.', 'Ferguson', 'Peter', '03 9520 4555', '636 St Kilda Road', 'Level 3', 'Melbourne', 'Victoria', '3004', 'Australia', 1611.0, 117300.0),
#  (119, 'La Rochelle Gifts', 'Labrune', 'Janine ', '40.67.8555', '67, rue des Cinquante Otages', None, 'Nantes', None, '44000', 'France', 1370.0, 118200.0),
#  (121, 'Baane Mini Imports', 'Bergulfsen', 'Jonas ', '07-98 9555', 'Erling Skakkes gate 78', None, 'Stavern', None, '4110', 'Norway', 1504.0, 81700.0),
#  (124, 'Mini Gifts Distributors Ltd.', 'Nelson', 'Susan', '4155551450', '5677 Strong St.', None, 'San Rafael', 'CA', '97562', 'USA', 1165.0, 210500.0),
# ...

# %%
# %%sql
#
# select *
# from employees
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [(1002, 'Murphy', 'Diane', 'x5800', 'dmurphy@classicmodelcars.com', '1', None, 'President'),
#  (1056, 'Patterson', 'Mary', 'x4611', 'mpatterso@classicmodelcars.com', '1', 1002.0, 'VP Sales'),
#  (1076, 'Firrelli', 'Jeff', 'x9273', 'jfirrelli@classicmodelcars.com', '1', 1002.0, 'VP Marketing'),
#  (1088, 'Patterson', 'William', 'x4871', 'wpatterson@classicmodelcars.com', '6', 1056.0, 'Sales Manager (APAC)'),
#  (1102, 'Bondur', 'Gerard', 'x5408', 'gbondur@classicmodelcars.com', '4', 1056.0, 'Sale Manager (EMEA)'),
#  (1143, 'Bow', 'Anthony', 'x5428', 'abow@classicmodelcars.com', '1', 1056.0, 'Sales Manager (NA)'),
#  (1165, 'Jennings', 'Leslie', 'x3291', 'ljennings@classicmodelcars.com', '1', 1143.0, 'Sales Rep'),
#  (1166, 'Thompson', 'Leslie', 'x4065', 'lthompson@classicmodelcars.com', '1', 1143.0, 'Sales Rep'),
# ...

# %%
# %%sql
#
# select *
# from offices
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 7 rows affected.
# [('1', 'San Francisco', '+1 650 219 4782', '100 Market Street', 'Suite 300', 'CA', 'USA', '94080', 'NA'),
#  ('2', 'Boston', '+1 215 837 0825', '1550 Court Place', 'Suite 102', 'MA', 'USA', '02107', 'NA'),
#  ('3', 'NYC', '+1 212 555 3000', '523 East 53rd Street', 'apt. 5A', 'NY', 'USA', '10022', 'NA'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", None, None, 'France', '75017', 'EMEA'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', None, 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan'),
#  ('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', None, 'Australia', 'NSW 2010', 'APAC'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', None, 'UK', 'EC2N 1HN', 'EMEA')]

# %%
# %%sql
#
# select *
# from orderdetails
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [(10100, 'S18_1749', 30, 136.0, 3),
#  (10100, 'S18_2248', 50, 55.09, 2),
#  (10100, 'S18_4409', 22, 75.46, 4),
#  (10100, 'S24_3969', 49, 35.29, 1),
#  (10101, 'S18_2325', 25, 108.06, 4),
#  (10101, 'S18_2795', 26, 167.06, 1),
#  (10101, 'S24_1937', 45, 32.53, 3),
#  (10101, 'S24_2022', 46, 44.35, 2),
#  (10102, 'S18_1342', 39, 95.55, 2),
#  (10102, 'S18_1367', 41, 43.13, 1)]

# %%
# %%sql
#
# select *
# from orders
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [(10100, datetime.datetime(2003, 1, 6, 0, 0), datetime.datetime(2003, 1, 13, 0, 0), datetime.datetime(2003, 1, 10, 0, 0), 'Shipped', None, 363),
#  (10101, datetime.datetime(2003, 1, 9, 0, 0), datetime.datetime(2003, 1, 18, 0, 0), datetime.datetime(2003, 1, 11, 0, 0), 'Shipped', 'Check on availability.', 128),
#  (10102, datetime.datetime(2003, 1, 10, 0, 0), datetime.datetime(2003, 1, 18, 0, 0), datetime.datetime(2003, 1, 14, 0, 0), 'Shipped', None, 181),
#  (10103, datetime.datetime(2003, 1, 29, 0, 0), datetime.datetime(2003, 2, 7, 0, 0), datetime.datetime(2003, 2, 2, 0, 0), 'Shipped', None, 121),
#  (10104, datetime.datetime(2003, 1, 31, 0, 0), datetime.datetime(2003, 2, 9, 0, 0), datetime.datetime(2003, 2, 1, 0, 0), 'Shipped', None, 141),
#  (10105, datetime.datetime(2003, 2, 11, 0, 0), datetime.datetime(2003, 2, 21, 0, 0), datetime.datetime(2003, 2, 12, 0, 0), 'Shipped', None, 145),
# ...

# %%
# %%sql
#
# select *
# from payments
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [(103, 'HQ336336', datetime.datetime(2004, 10, 19, 0, 0), 6066.78),
#  (103, 'JM555205', datetime.datetime(2003, 6, 5, 0, 0), 14571.44),
#  (103, 'OM314933', datetime.datetime(2004, 12, 18, 0, 0), 1676.14),
#  (112, 'BO864823', datetime.datetime(2004, 12, 17, 0, 0), 14191.12),
#  (112, 'HQ55022', datetime.datetime(2003, 6, 6, 0, 0), 32641.98),
#  (112, 'ND748579', datetime.datetime(2004, 8, 20, 0, 0), 33347.88),
#  (114, 'GG31455', datetime.datetime(2003, 5, 20, 0, 0), 45864.03),
#  (114, 'MA765515', datetime.datetime(2004, 12, 15, 0, 0), 82261.22),
#  (114, 'NP603840', datetime.datetime(2003, 5, 31, 0, 0), 7565.08),
#  (114, 'NR27552', datetime.datetime(2004, 3, 10, 0, 0), 44894.74)]

# %%
# %%sql
#
# select *
# from productlines
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 7 rows affected.
# [('Classic Cars', 'Attention car enthusiasts: Make your wildest car ownership dreams come true. Whether you are looking for classic muscle cars, dream sports cars or mo ... (437 characters truncated) ... cles. All models include a certificate of authenticity from their manufacturers and come fully assembled and ready for display in the home or office.', None, None),
#  ('Motorcycles', 'Our motorcycles are state of the art replicas of classic as well as contemporary motorcycle legends such as Harley Davidson, Ducati and Vespa. Models ... (297 characters truncated) ...  out-of-production vehicles. All models come fully assembled and ready for display in the home or office. Most include a certificate of authenticity.', None, None),
# ...

# %%
# %%sql
#
# select *
# from products
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', 7933, 48.81, 95.7),
#  ('S10_1949', '1952 Alpine Renault 1300', 'Classic Cars', '1:10', 'Classic Metal Creations', 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 7305, 98.58, 214.3),
# ...

# %% [markdown]
# # **EJERCICIOS**

# %% [markdown]
# 1. Obtén todos los registros de la tabla customers.

# %%
# %%sql
#  SELECT * FROM customers
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 122 rows affected.
# [(103, 'Atelier graphique', 'Schmitt', 'Carine ', '40.32.2555', '54, rue Royale', None, 'Nantes', None, '44000', 'France', 1370.0, 21000.0),
#  (112, 'Signal Gift Stores', 'King', 'Jean', '7025551838', '8489 Strong St.', None, 'Las Vegas', 'NV', '83030', 'USA', 1166.0, 71800.0),
#  (114, 'Australian Collectors, Co.', 'Ferguson', 'Peter', '03 9520 4555', '636 St Kilda Road', 'Level 3', 'Melbourne', 'Victoria', '3004', 'Australia', 1611.0, 117300.0),
#  (119, 'La Rochelle Gifts', 'Labrune', 'Janine ', '40.67.8555', '67, rue des Cinquante Otages', None, 'Nantes', None, '44000', 'France', 1370.0, 118200.0),
#  (121, 'Baane Mini Imports', 'Bergulfsen', 'Jonas ', '07-98 9555', 'Erling Skakkes gate 78', None, 'Stavern', None, '4110', 'Norway', 1504.0, 81700.0),
#  (124, 'Mini Gifts Distributors Ltd.', 'Nelson', 'Susan', '4155551450', '5677 Strong St.', None, 'San Rafael', 'CA', '97562', 'USA', 1165.0, 210500.0),
# ...

# %% [markdown]
# 2. Muestra todos los productos de la tabla products cuyo precio de compra (buyPrice) sea mayor a 50.

# %%
# %%sql
# SELECT * FROM products WHERE "buyPrice" > 50
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 62 rows affected.
# [('S10_1949', '1952 Alpine Renault 1300', 'Classic Cars', '1:10', 'Classic Metal Creations', 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 7305, 98.58, 214.3),
#  ('S10_2016', '1996 Moto Guzzi 1100i', 'Motorcycles', '1:10', 'Highway 66 Mini Classics', 'Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leathe ... (93 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', 6625, 68.99, 118.94),
# ...

# %% [markdown]
# 3. Lista los empleados que trabajan en la oficina con código officeCode igual a 1.

# %%
# %%sql
# SELECT * FROM employees WHERE "officeCode" = '1'
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 6 rows affected.
# [(1002, 'Murphy', 'Diane', 'x5800', 'dmurphy@classicmodelcars.com', '1', None, 'President'),
#  (1056, 'Patterson', 'Mary', 'x4611', 'mpatterso@classicmodelcars.com', '1', 1002.0, 'VP Sales'),
#  (1076, 'Firrelli', 'Jeff', 'x9273', 'jfirrelli@classicmodelcars.com', '1', 1002.0, 'VP Marketing'),
#  (1143, 'Bow', 'Anthony', 'x5428', 'abow@classicmodelcars.com', '1', 1056.0, 'Sales Manager (NA)'),
#  (1165, 'Jennings', 'Leslie', 'x3291', 'ljennings@classicmodelcars.com', '1', 1143.0, 'Sales Rep'),
#  (1166, 'Thompson', 'Leslie', 'x4065', 'lthompson@classicmodelcars.com', '1', 1143.0, 'Sales Rep')]

# %% [markdown]
# 4. Encuentra todos los clientes cuyo nombre (customerName) comienza con la letra 'A'.

# %%
# %%sql
# SELECT * FROM customers WHERE "customerName" LIKE 'A%'
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 16 rows affected.
# [(103, 'Atelier graphique', 'Schmitt', 'Carine ', '40.32.2555', '54, rue Royale', None, 'Nantes', None, '44000', 'France', 1370.0, 21000.0),
#  (114, 'Australian Collectors, Co.', 'Ferguson', 'Peter', '03 9520 4555', '636 St Kilda Road', 'Level 3', 'Melbourne', 'Victoria', '3004', 'Australia', 1611.0, 117300.0),
#  (168, 'American Souvenirs Inc', 'Franco', 'Keith', '2035557845', '149 Spinnaker Dr.', 'Suite 101', 'New Haven', 'CT', '97823', 'USA', 1286.0, 0.0),
#  (187, 'AV Stores, Co.', 'Ashworth', 'Rachel', '(171) 555-1555', 'Fauntleroy Circus', None, 'Manchester', None, 'EC2 5NT', 'UK', 1501.0, 136800.0),
#  (198, 'Auto-Moto Classics Inc.', 'Taylor', 'Leslie', '6175558428', '16780 Pompton St.', None, 'Brickhaven', 'MA', '58339', 'USA', 1216.0, 23000.0),
# ...

# %% [markdown]
# 5. Cuenta cuántos pedidos (orders) ha realizado el cliente con número de cliente (customerNumber) 103.

# %%
# %%sql
# SELECT COUNT(*) FROM orders WHERE "customerNumber" = 103
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [(3,)]

# %% [markdown]
# 6. Calcula el total de pagos realizados por el cliente con número de cliente 112.

# %%
# %%sql
# SELECT SUM("amount") FROM payments WHERE "customerNumber" = 112
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [(80180.98,)]

# %% [markdown]
# 7. Encuentra el producto con el precio de compra más alto en la tabla products.

# %%
# %%sql
# SELECT * FROM products ORDER BY "buyPrice" DESC LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [('S10_4962', '1962 LanciaA Delta 16V', 'Classic Cars', '1:10', 'Second Gear Diecast', 'Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 6791, 103.42, 147.74)]

# %% [markdown]
# 8. Muestra los 5 productos más vendidos según la cantidad pedida en orderdetails.

# %%
# %%sql
# SELECT * FROM products a
# INNER JOIN orderdetails b on b."productCode" = a."productCode"
# ORDER BY b."quantityOrdered" DESC LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 5 rows affected.
# [('S12_4675', '1969 Dodge Charger', 'Classic Cars', '1:12', 'Welly Diecast Productions', 'Detailed model of the 1969 Dodge Charger. This model includes finely detailed interior and exterior features. Painted in red and white.', 7323, 58.73, 115.16, 10405, 'S12_4675', 97, 115.16, 5),
#  ('S18_3278', '1969 Dodge Super Bee', 'Classic Cars', '1:18', 'Min Lin Diecast', 'This replica features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.', 1917, 49.05, 80.41, 10404, 'S18_3278', 90, 67.54, 6),
#  ('S700_2466', 'America West Airlines B757-200', 'Planes', '1:700', 'Motor City Art Classics', 'Official logos and insignias. Working steering system. Rotating jet engines', 9653, 68.8, 99.72, 10401, 'S700_2466', 85, 98.72, 10),
# ...

# %% [markdown]
# 9. Lista todas las oficinas y el número de empleados que trabajan en cada una.

# %%
# %%sql
# SELECT a."officeCode", COUNT(b."employeeNumber") as CantidadEmpleados FROM offices a
# INNER JOIN employees b on b."officeCode" = a."officeCode"
# GROUP BY a."officeCode"
# ORDER BY CantidadEmpleados DESC
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 7 rows affected.
# [('1', 6), ('4', 5), ('6', 4), ('5', 2), ('3', 2), ('7', 2), ('2', 2)]

# %% [markdown]
# 10. Encuentra el número total de clientes atendidos por cada representante de ventas (salesRepEmployeeNumber).

# %%
# %%sql
# SELECT "salesRepEmployeeNumber", COUNT(*) FROM customers
# GROUP BY "salesRepEmployeeNumber"
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 16 rows affected.
# [(None, 22),
#  (1504.0, 9),
#  (1323.0, 8),
#  (1166.0, 6),
#  (1702.0, 6),
#  (1165.0, 6),
#  (1501.0, 8),
#  (1611.0, 5),
#  (1286.0, 7),
#  (1612.0, 5),
#  (1401.0, 10),
#  (1370.0, 7),
#  (1188.0, 6),
#  (1621.0, 5),
#  (1337.0, 6),
#  (1216.0, 6)]

# %% [markdown]
# 11. Muestra todos los productos y su línea de producto (productLine), ordenados alfabéticamente por línea de producto.

# %%
# %%sql
# SELECT p."productName", p."productLine"	 FROM products p
# ORDER BY p."productLine", p."productName";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 110 rows affected.
# [('1948 Porsche 356-A Roadster', 'Classic Cars'),
#  ('1948 Porsche Type 356 Roadster', 'Classic Cars'),
#  ('1949 Jaguar XK 120', 'Classic Cars'),
#  ('1952 Alpine Renault 1300', 'Classic Cars'),
#  ('1952 Citroen-15CV', 'Classic Cars'),
#  ('1956 Porsche 356A Coupe', 'Classic Cars'),
#  ('1957 Corvette Convertible', 'Classic Cars'),
#  ('1957 Ford Thunderbird', 'Classic Cars'),
#  ('1958 Chevy Corvette Limited Edition', 'Classic Cars'),
#  ('1961 Chevrolet Impala', 'Classic Cars'),
#  ('1962 LanciaA Delta 16V', 'Classic Cars'),
#  ('1965 Aston Martin DB5', 'Classic Cars'),
#  ('1966 Shelby Cobra 427 S/C', 'Classic Cars'),
#  ('1968 Dodge Charger', 'Classic Cars'),
#  ('1968 Ford Mustang', 'Classic Cars'),
#  ('1969 Chevrolet Camaro Z28', 'Classic Cars'),
#  ('1969 Corvair Monza', 'Classic Cars'),
#  ('1969 Dodge Charger', 'Classic Cars'),
#  ('1969 Dodge Super Bee', 'Classic Cars'),
# ...

# %% [markdown]
# 12. Calcula el importe total de todas las órdenes sumando el resultado de quantityOrdered por priceEach en orderdetails.

# %%
# %%sql
# SELECT SUM(o."quantityOrdered" * o."priceEach") AS total_importe
# FROM orderdetails o;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [(9604190.609999985,)]

# %% [markdown]
# 13. Encuentra todos los pedidos que han sido enviados después del 1 de enero de 2004.

# %%
# %%sql
# SELECT * FROM orders o
#    WHERE o."shippedDate" > '2004-01-01';
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 202 rows affected.
# [(10266, datetime.datetime(2004, 7, 6, 0, 0), datetime.datetime(2004, 7, 14, 0, 0), datetime.datetime(2004, 7, 10, 0, 0), 'Shipped', None, 386),
#  (10267, datetime.datetime(2004, 7, 7, 0, 0), datetime.datetime(2004, 7, 17, 0, 0), datetime.datetime(2004, 7, 9, 0, 0), 'Shipped', None, 151),
#  (10208, datetime.datetime(2004, 1, 2, 0, 0), datetime.datetime(2004, 1, 11, 0, 0), datetime.datetime(2004, 1, 4, 0, 0), 'Shipped', None, 146),
#  (10209, datetime.datetime(2004, 1, 9, 0, 0), datetime.datetime(2004, 1, 15, 0, 0), datetime.datetime(2004, 1, 12, 0, 0), 'Shipped', None, 347),
#  (10210, datetime.datetime(2004, 1, 12, 0, 0), datetime.datetime(2004, 1, 22, 0, 0), datetime.datetime(2004, 1, 20, 0, 0), 'Shipped', None, 177),
#  (10211, datetime.datetime(2004, 1, 15, 0, 0), datetime.datetime(2004, 1, 25, 0, 0), datetime.datetime(2004, 1, 18, 0, 0), 'Shipped', None, 406),
# ...

# %% [markdown]
# 14. Lista los clientes y sus pagos totales, ordenados de mayor a menor.

# %%
# %%sql
# SELECT p."customerNumber", SUM(p."amount") AS total_pagos
#    FROM payments p
#    GROUP BY p."customerNumber"
#    ORDER BY total_pagos DESC;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 98 rows affected.
# [(141, 715738.9800000001),
#  (124, 584188.2400000001),
#  (114, 180585.06999999998),
#  (151, 177913.95),
#  (148, 156251.03),
#  (323, 154622.08000000002),
#  (187, 148410.09),
#  (276, 137034.22),
#  (321, 132340.78),
#  (146, 130305.35),
#  (278, 127529.69),
#  (353, 126983.19),
#  (119, 116949.68000000001),
#  (363, 116449.29000000001),
#  (496, 114497.19),
#  (458, 112440.09),
#  (298, 108777.92),
#  (131, 107639.94),
#  (145, 107446.5),
#  (398, 105548.73),
#  (166, 105420.56999999999),
#  (161, 104545.22),
#  (121, 104224.79),
#  (334, 103896.73999999999),
#  (320, 101872.51999999999),
#  (157, 98509.25),
#  (167, 97562.47),
#  (311, 95706.15),
#  (186, 95546.46),
#  (175, 95424.63),
#  (205, 93803.29999999999),
#  (282, 91655.61),
#  (286, 90545.37),
#  (386, 90143.31),
#  (227, 89909.79999999999),
#  (259, 89223.14),
#  (462, 88627.49),
#  (385, 87468.3),
#  (172, 86553.52),
#  (406, 86436.97),
# ...

# %% [markdown]
# 15. Muestra los empleados que no reportan a ningún gerente (es decir, cuyo campo reportsTo es NULL).

# %%
# %%sql
# SELECT * FROM employees e
#    WHERE e."reportsTo" IS NULL;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [(1002, 'Murphy', 'Diane', 'x5800', 'dmurphy@classicmodelcars.com', '1', None, 'President')]

# %% [markdown]
# 16. Encuentra los clientes que no han realizado ningún pedido.

# %%
# %%sql
# SELECT * FROM customers c
# WHERE c."customerNumber" NOT IN (SELECT o."customerNumber" FROM orders o);
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 24 rows affected.
# [(125, 'Havel & Zbyszek Co', 'Piestrzeniewicz', 'Zbyszek ', '(26) 642-7555', 'ul. Filtrowa 68', None, 'Warszawa', None, '01-012', 'Poland', None, 0.0),
#  (168, 'American Souvenirs Inc', 'Franco', 'Keith', '2035557845', '149 Spinnaker Dr.', 'Suite 101', 'New Haven', 'CT', '97823', 'USA', 1286.0, 0.0),
#  (169, 'Porto Imports Co.', 'de Castro', 'Isabel ', '(1) 356-5555', 'Estrada da saúde n. 58', None, 'Lisboa', None, '1756', 'Portugal', None, 0.0),
#  (206, 'Asian Shopping Network, Co', 'Walker', 'Brydey', '+612 9411 1555', 'Suntec Tower Three', '8 Temasek', 'Singapore', None, '038988', 'Singapore', None, 0.0),
#  (223, 'Natürlich Autos', 'Kloss', 'Horst ', '0372-555188', 'Taucherstraße 10', None, 'Cunewalde', None, '01307', 'Germany', None, 0.0),
#  (237, 'ANG Resellers', 'Camino', 'Alejandra ', '(91) 745 6555', 'Gran Vía, 1', None, 'Madrid', None, '28001', 'Spain', None, 0.0),
# ...

# %% [markdown]
# 17. Muestra los productos que nunca han sido vendidos en ningún pedido.

# %%
# %%sql
# SELECT * FROM products p
# WHERE p."productCode" NOT IN (SELECT o."productCode" FROM orderdetails o);
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [('S18_3233', '1985 Toyota Supra', 'Classic Cars', '1:18', 'Highway 66 Mini Classics', 'This model features soft rubber tires, working steering, rubber mud guards, authentic Ford logos, detailed undercarriage, opening doors and hood, removable split rear gate, full size spare mounted in bed, detailed interior with opening glove box', 7733, 57.01, 107.57)]

# %% [markdown]
# 18. Calcula el precio de compra promedio de todos los productos.

# %%
# %%sql
# SELECT AVG(p."buyPrice") AS precio_promedio FROM products p;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [(54.395181818181825,)]

# %% [markdown]
# 19. Lista los clientes y el número de pedidos que han realizado.

# %%
# %%sql
# SELECT o."customerNumber", COUNT(o."orderNumber") AS numero_pedidos
# FROM orders o
# GROUP BY o."customerNumber";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 98 rows affected.
# [(209, 3),
#  (347, 2),
#  (455, 2),
#  (181, 3),
#  (321, 4),
#  (205, 3),
#  (448, 3),
#  (146, 3),
#  (201, 3),
#  (350, 3),
#  (333, 3),
#  (382, 4),
#  (314, 3),
#  (386, 3),
#  (216, 3),
#  (278, 3),
#  (450, 4),
#  (406, 3),
#  (424, 3),
#  (484, 2),
#  (233, 3),
#  (334, 3),
#  (144, 4),
#  (462, 3),
#  (299, 2),
#  (276, 4),
#  (471, 3),
#  (473, 2),
#  (219, 2),
#  (175, 3),
#  (363, 3),
#  (362, 3),
#  (379, 3),
#  (323, 5),
#  (320, 3),
#  (114, 5),
#  (415, 1),
#  (167, 3),
#  (112, 3),
#  (475, 2),
#  (487, 2),
#  (458, 3),
#  (124, 17),
#  (452, 3),
#  (227, 2),
#  (128, 4),
#  (282, 4),
#  (173, 2),
#  (339, 2),
#  (166, 4),
#  (311, 3),
#  (103, 3),
#  (344, 2),
#  (385, 3),
#  (189, 2),
#  (239, 2),
#  (161, 4),
#  (121, 4),
#  (119, 4),
#  (286, 2),
#  (240, 2),
#  (328, 3),
#  (157, 4),
#  (202, 2),
#  (260, 2),
#  (381, 4),
#  (412, 3),
#  (447, 3),
#  (187, 3),
#  (298, 2),
#  (259, 2),
# ...

# %% [markdown]
# 20. Encuentra el total de ventas por año.

# %%
# %%sql
# SELECT EXTRACT(YEAR FROM o."orderDate") AS order_year,
#        SUM(od."quantityOrdered" * od."priceEach") AS total_sales
# FROM orders o
# JOIN orderdetails od ON o."orderNumber" = od."orderNumber"
# GROUP BY order_year
# ORDER BY order_year;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 3 rows affected.
# [(Decimal('2003'), 3317348.389999999),
#  (Decimal('2004'), 4515905.510000002),
#  (Decimal('2005'), 1770936.7099999993)]

# %% [markdown]
# 21. Muestra los detalles de las órdenes combinados con la información del producto para cada artículo.

# %%
# %%sql
# SELECT o."orderNumber", o."orderDate", od."productCode", p."productName", od."quantityOrdered", od."priceEach"
# FROM orders o
# JOIN orderdetails od ON o."orderNumber" = od."orderNumber"
# JOIN products p ON od."productCode" = p."productCode";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 2996 rows affected.
# [(10100, datetime.datetime(2003, 1, 6, 0, 0), 'S18_1749', '1917 Grand Touring Sedan', 30, 136.0),
#  (10100, datetime.datetime(2003, 1, 6, 0, 0), 'S18_2248', '1911 Ford Town Car', 50, 55.09),
#  (10100, datetime.datetime(2003, 1, 6, 0, 0), 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 22, 75.46),
#  (10100, datetime.datetime(2003, 1, 6, 0, 0), 'S24_3969', '1936 Mercedes Benz 500k Roadster', 49, 35.29),
#  (10101, datetime.datetime(2003, 1, 9, 0, 0), 'S18_2325', '1932 Model A Ford J-Coupe', 25, 108.06),
#  (10101, datetime.datetime(2003, 1, 9, 0, 0), 'S18_2795', '1928 Mercedes-Benz SSK', 26, 167.06),
#  (10101, datetime.datetime(2003, 1, 9, 0, 0), 'S24_1937', '1939 Chevrolet Deluxe Coupe', 45, 32.53),
#  (10101, datetime.datetime(2003, 1, 9, 0, 0), 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 46, 44.35),
# ...

# %% [markdown]
# 22. Encuentra los empleados que trabajan en oficinas ubicadas en los Estados Unidos.

# %%
# %%sql
# SELECT e.* FROM employees e
# JOIN offices o ON e."officeCode" = o."officeCode"
# WHERE o."country" = 'USA';
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 10 rows affected.
# [(1002, 'Murphy', 'Diane', 'x5800', 'dmurphy@classicmodelcars.com', '1', None, 'President'),
#  (1056, 'Patterson', 'Mary', 'x4611', 'mpatterso@classicmodelcars.com', '1', 1002.0, 'VP Sales'),
#  (1076, 'Firrelli', 'Jeff', 'x9273', 'jfirrelli@classicmodelcars.com', '1', 1002.0, 'VP Marketing'),
#  (1143, 'Bow', 'Anthony', 'x5428', 'abow@classicmodelcars.com', '1', 1056.0, 'Sales Manager (NA)'),
#  (1165, 'Jennings', 'Leslie', 'x3291', 'ljennings@classicmodelcars.com', '1', 1143.0, 'Sales Rep'),
#  (1166, 'Thompson', 'Leslie', 'x4065', 'lthompson@classicmodelcars.com', '1', 1143.0, 'Sales Rep'),
#  (1188, 'Firrelli', 'Julie', 'x2173', 'jfirrelli@classicmodelcars.com', '2', 1143.0, 'Sales Rep'),
#  (1216, 'Patterson', 'Steve', 'x4334', 'spatterson@classicmodelcars.com', '2', 1143.0, 'Sales Rep'),
#  (1286, 'Tseng', 'Foon Yue', 'x2248', 'ftseng@classicmodelcars.com', '3', 1143.0, 'Sales Rep'),
# ...

# %% [markdown]
# 23. Lista los clientes junto con el nombre de su representante de ventas.

# %%
# %%sql
# SELECT c."customerName", e."firstName", e."lastName"
# FROM customers c
# JOIN employees e ON c."salesRepEmployeeNumber" = e."employeeNumber";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 100 rows affected.
# [('Signal Collectibles Ltd.', 'Leslie', 'Jennings'),
#  ('The Sharp Gifts Warehouse', 'Leslie', 'Jennings'),
#  ('Corporate Gift Ideas Co.', 'Leslie', 'Jennings'),
#  ('Technics Stores Inc.', 'Leslie', 'Jennings'),
#  ('Mini Wheels Co.', 'Leslie', 'Jennings'),
#  ('Mini Gifts Distributors Ltd.', 'Leslie', 'Jennings'),
#  ('West Coast Collectables Co.', 'Leslie', 'Thompson'),
#  ("Men 'R' US Retailers, Ltd.", 'Leslie', 'Thompson'),
#  ('Collectable Mini Designs Co.', 'Leslie', 'Thompson'),
#  ('Boards & Toys Co.', 'Leslie', 'Thompson'),
#  ('Toys4GrownUps.com', 'Leslie', 'Thompson'),
#  ('Signal Gift Stores', 'Leslie', 'Thompson'),
#  ('Diecast Collectables', 'Julie', 'Firrelli'),
#  ('Collectables For Less Inc.', 'Julie', 'Firrelli'),
#  ('Classic Gift Ideas, Inc', 'Julie', 'Firrelli'),
#  ('Mini Creations Ltd.', 'Julie', 'Firrelli'),
#  ('Online Mini Collectables', 'Julie', 'Firrelli'),
# ...

# %% [markdown]
# 24. Calcula el total de pagos recibidos en cada ciudad.

# %%
# %%sql
# SELECT o."city", SUM(p."amount") AS total_pagos
# FROM payments p
# INNER JOIN customers c ON p."customerNumber" = c."customerNumber"
# INNER JOIN offices o ON c."salesRepEmployeeNumber"::text = o."officeCode"
# GROUP BY o."city";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 0 rows affected.
# []

# %% [markdown]
# 25. Muestra los productos que tienen menos de 100 unidades en stock (quantityInStock).

# %%
# %%sql
# SELECT * FROM products WHERE "quantityInStock" < 100;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 2 rows affected.
# [('S12_1099', '1968 Ford Mustang', 'Classic Cars', '1:12', 'Autoart Studio Design', 'Hood, doors and trunk all open to reveal highly detailed interior features. Steering wheel actually turns the front wheels. Color dark green.', 68, 95.34, 194.57),
#  ('S24_2000', '1960 BSA Gold Star DBD34', 'Motorcycles', '1:24', 'Highway 66 Mini Classics', 'Detailed scale replica with working suspension and constructed from over 70 parts', 15, 37.32, 76.17)]

# %% [markdown]
# 26. Encuentra los clientes que han realizado pedidos con un monto total superior a $10,000.

# %%
# %%sql
# SELECT c."customerNumber", c."customerName", SUM(od."quantityOrdered" * od."priceEach") AS monto_total
# FROM customers c
# JOIN orders o ON c."customerNumber" = o."customerNumber"
# JOIN orderdetails od ON o."orderNumber" = od."orderNumber"
# GROUP BY c."customerNumber", c."customerName"
# HAVING SUM(od."quantityOrdered" * od."priceEach") > 10000;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 97 rows affected.
# [(475, 'West Coast Collectables Co.', 43748.719999999994),
#  (379, 'Collectables For Less Inc.', 73533.65000000001),
#  (350, 'Marseille Mini Autos', 71547.53),
#  (339, 'Classic Gift Ideas, Inc', 57939.340000000004),
#  (452, 'Mini Auto Werke', 51059.99),
#  (129, 'Mini Wheels Co.', 66710.56),
#  (175, 'Gift Depot Inc.', 95424.63),
#  (344, 'CAF Imports', 46751.14000000001),
#  (216, 'Enaco Distributors', 68520.47),
#  (385, 'Cruz & Sons Co.', 87468.29999999999),
#  (124, 'Mini Gifts Distributors Ltd.', 591827.3399999996),
#  (242, 'Alpha Cognac', 60483.359999999986),
#  (119, 'La Rochelle Gifts', 158573.11999999997),
#  (189, 'Clover Collections, Co.', 49898.270000000004),
#  (398, 'Tokyo Collectables, Ltd', 105548.73000000001),
#  (260, 'Royal Canadian Collectables, Ltd.', 66812.0),
#  (363, 'Online Diecast Creations Co.', 116449.29000000001),
#  (186, 'Toys of Finland, Co.', 95546.46),
# ...

# %% [markdown]
# 27. Lista los empleados y el número de clientes que atienden.

# %%
# %%sql
# SELECT e."employeeNumber", e."firstName", e."lastName", COUNT(c."customerNumber") AS numero_clientes
# FROM employees e
# LEFT JOIN customers c ON e."employeeNumber" = c."salesRepEmployeeNumber"
# GROUP BY e."employeeNumber", e."firstName", e."lastName";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 23 rows affected.
# [(1504, 'Barry', 'Jones', 9),
#  (1612, 'Peter', 'Marsh', 5),
#  (1188, 'Julie', 'Firrelli', 6),
#  (1619, 'Tom', 'King', 0),
#  (1337, 'Loui', 'Bondur', 6),
#  (1088, 'William', 'Patterson', 0),
#  (1501, 'Larry', 'Bott', 8),
#  (1165, 'Leslie', 'Jennings', 6),
#  (1621, 'Mami', 'Nishi', 5),
#  (1286, 'Foon Yue', 'Tseng', 7),
#  (1056, 'Mary', 'Patterson', 0),
#  (1166, 'Leslie', 'Thompson', 6),
#  (1625, 'Yoshimi', 'Kato', 0),
#  (1216, 'Steve', 'Patterson', 6),
#  (1076, 'Jeff', 'Firrelli', 0),
#  (1370, 'Gerard', 'Hernandez', 7),
#  (1702, 'Martin', 'Gerard', 6),
#  (1143, 'Anthony', 'Bow', 0),
#  (1323, 'George', 'Vanauf', 8),
#  (1102, 'Gerard', 'Bondur', 0),
#  (1401, 'Pamela', 'Castillo', 10),
#  (1611, 'Andy', 'Fixter', 5),
#  (1002, 'Diane', 'Murphy', 0)]

# %% [markdown]
# 28. Calcula el importe total de los pedidos que están en proceso (estado 'In Process').

# %%
# %%sql
# SELECT SUM(od."quantityOrdered" * od."priceEach") AS total_importe_en_proceso
# FROM orders o
# JOIN orderdetails od ON o."orderNumber" = od."orderNumber"
# WHERE o."status" = 'In Process';
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 1 rows affected.
# [(135271.52,)]

# %% [markdown]
# 29. Encuentra los productos que han sido pedidos más de 100 veces en total.

# %%
# %%sql
# SELECT "productCode", SUM("quantityOrdered") AS total_cantidad_pedida
# FROM orderdetails
# GROUP BY "productCode"
# HAVING SUM("quantityOrdered") > 100;
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 109 rows affected.
# [('S32_2206', Decimal('906')),
#  ('S700_2466', Decimal('984')),
#  ('S700_3505', Decimal('952')),
#  ('S700_2824', Decimal('997')),
#  ('S18_2949', Decimal('1038')),
#  ('S50_4713', Decimal('992')),
#  ('S12_3380', Decimal('925')),
#  ('S24_4278', Decimal('1009')),
#  ('S10_2016', Decimal('999')),
#  ('S18_2325', Decimal('957')),
#  ('S18_1889', Decimal('972')),
#  ('S18_2795', Decimal('880')),
#  ('S18_4933', Decimal('767')),
#  ('S10_1678', Decimal('1057')),
#  ('S24_3420', Decimal('884')),
#  ('S24_2766', Decimal('949')),
#  ('S18_3320', Decimal('992')),
#  ('S18_3140', Decimal('883')),
#  ('S24_2840', Decimal('983')),
#  ('S24_2300', Decimal('1029')),
#  ('S18_4600', Decimal('1061')),
#  ('S24_2360', Decimal('947')),
#  ('S18_4027', Decimal('945')),
#  ('S18_1984', Decimal('917')),
#  ('S12_1666', Decimal('972')),
#  ('S24_1628', Decimal('915')),
#  ('S24_2000', Decimal('1015')),
# ...

# %% [markdown]
# 30. Muestra las líneas de productos y el número de productos que pertenecen a cada línea.

# %%
# %%sql
# SELECT "productLine", COUNT("productCode") AS numero_productos
# FROM products
# GROUP BY "productLine";
# Out:
#  * postgresql://postgres:***@localhost/classicmodels
# 7 rows affected.
# [('Classic Cars', 38),
#  ('Trains', 3),
#  ('Planes', 12),
#  ('Trucks and Buses', 11),
#  ('Vintage Cars', 24),
#  ('Motorcycles', 13),
#  ('Ships', 9)]
